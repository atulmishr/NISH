# %%
#import the libraries
import numpy as np

# %%
#Ques1-numpy array with 10 elems. and shape(10,1)
p=np.random.random((10,1))
print(p)
np.mean(p)
# Out:
# [[0.8688975 ]
#  [0.81034952]
#  [0.95837385]
#  [0.22135177]
#  [0.09670316]
#  [0.62748492]
#  [0.35590367]
#  [0.1789352 ]
#  [0.51492933]
#  [0.01656725]]
# 0.46494961522892764

# %%
#Ques2-Another Array with 20Elems. and (20,1)shape
n=np.random.random((20,1))
print(n)
x=np.var(n)
print(x)
y=np.std(n)
print(n)
# Out:
# [[0.01571498]
#  [0.48028657]
#  [0.50425395]
#  [0.88155331]
#  [0.37821012]
#  [0.38454683]
#  [0.27702092]
#  [0.45754407]
#  [0.90578963]
#  [0.58112508]
#  [0.71782242]
#  [0.53749827]
#  [0.0564811 ]
#  [0.08110223]
#  [0.22831489]
#  [0.72477216]
#  [0.88125292]
#  [0.79946325]
#  [0.43779176]
#  [0.75876427]]
# 0.07411434850695837
# [[0.01571498]
#  [0.48028657]
#  [0.50425395]
#  [0.88155331]
#  [0.37821012]
#  [0.38454683]
#  [0.27702092]
#  [0.45754407]
#  [0.90578963]
#  [0.58112508]
#  [0.71782242]
#  [0.53749827]
#  [0.0564811 ]
#  [0.08110223]
#  [0.22831489]
#  [0.72477216]
#  [0.88125292]
#  [0.79946325]
#  [0.43779176]
#  [0.75876427]]

# %%
#Ques3-given array with diff-2 shapes and perform all funcs. acc2 ques.
A=np.random.random((10,20))
print(A)
B=np.random.random((20,25))
print(B)
C=A.dot(B)
print(C)
C.sum()
# Out:
# [[0.04673903 0.0224764  0.33619163 0.01260103 0.57784597 0.30801275
#   0.20541337 0.17145872 0.72156146 0.26732472 0.503921   0.1398101
#   0.05273435 0.54691274 0.24501815 0.78978043 0.41412039 0.69321015
#   0.79602218 0.53566973]
#  [0.54253975 0.08929771 0.87640635 0.65052976 0.71207316 0.93966757
#   0.21393762 0.12309998 0.54887674 0.16749598 0.4656741  0.19137094
#   0.47512589 0.02438714 0.47992835 0.9084745  0.61368278 0.37251969
#   0.48866047 0.45808717]
#  [0.65351475 0.7805129  0.29580015 0.86107318 0.75859806 0.32933123
#   0.97318907 0.85126652 0.48813903 0.84732673 0.66064199 0.81931127
#   0.04348957 0.05770955 0.38728562 0.19992297 0.95474951 0.84314775
#   0.42826809 0.10555456]
#  [0.23065636 0.17974907 0.90155719 0.40284563 0.65913347 0.51690696
#   0.07096305 0.52551491 0.18517191 0.75892603 0.08263068 0.35261126
#   0.24177115 0.97961231 0.80058957 0.87062513 0.6000133  0.82083994
#   0.3529188  0.70799972]
# ...

# %%
#Ques4-create Array and generate a new array with the help of given func.[1/(1+np.exp(a))]
A=np.random.random((10,1))
print("old array is:",A)
B=1/(1+np.exp(-A))
print("new array is:",B)
# Out:
# ('old array is:', array([[0.22768916],
#        [0.54009464],
#        [0.80498075],
#        [0.56863551],
#        [0.21930356],
#        [0.82878984],
#        [0.50210731],
#        [0.71879483],
#        [0.15497623],
#        [0.14296851]]))
# ('new array is:', array([[0.55667764],
#        [0.63183443],
#        [0.6910389 ],
#        [0.63844827],
#        [0.55460721],
#        [0.69609899],
#        [0.62295443],
#        [0.67234158],
#        [0.5386667 ],
#        [0.53568137]]))
