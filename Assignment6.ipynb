# %%
#libraries
#import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df1=pd.read_csv('https://raw.githubusercontent.com/Shreyas3108/Weather/master/weather.csv')
#print(df1)
df1=np.random.normal(size=50)
sns.distplot(df1);

# %%
sns.distplot(df1,kde=False,rug=True);

# %%
sns.kdeplot(df1,shade=True);
